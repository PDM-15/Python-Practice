# %% [markdown]
# <a href="https://colab.research.google.com/github/PDM-15/Python-Practice/blob/main/py1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Python Program to Exchange the Values of Two Numbers Without Using a

# %%
a = 20
b = 10

a = a+b
b = a-b
a = a-b

print(a,b)
# Out:
# 10 20

# %% [markdown]
# Python Program to Check Whether a Number is Positive or Negative

# %%
a = -10
if a<0:
  print("negative")
elif a == 0:
  print("Zero")
else:
  print("positive")
# Out:
# negative

# %% [markdown]
# Python Program to Print all Numbers in a Range Divisible by a Given Number. (if range is from 1
# to 20 and number is 4, then the result should be 4, 8, 12, 16 and 20)

# %%
#x = [range(1,20)]
n = 4
#L1 = [x for i in x if i%n==0]
for i in range(1,21):
  if i%n==0:
    print(i)
# Out:
# 4
# 8
# 12
# 16
# 20

# %% [markdown]
# Python Program to Read Two Numbers and Print Their Quotient and Remainder.

# %%
a = int(input("First Number:"))
b = int(input("Second Number:"))
print(f"Quotient:{a/b} and Remainder:{a%b}")
# Out:
# First Number:8
# Second Number:16
# Quotient:0.5 and Remainder:8

# %% [markdown]
# Python Program to Print Odd Numbers Within a Given Range

# %%
for i in range(1,16):
  if i%2!=0:
    print(i)
# Out:
# 1
# 3
# 5
# 7
# 9
# 11
# 13
# 15

# %% [markdown]
# Python Program to Find the Sum of Digits in a Number

# %%
x = input("Number")
L = list(x)
sum = 0
for i in L:
  sum += int(i)
print(sum)
# Out:
# Number123
# 6

# %% [markdown]
# Python Program to Find the Smallest Divisor of an Integer.

# %%
x = 456
L = []
for i in range(2,10):
  if x%i == 0:
    L.append(i)
print(L[0])
# Out:
# 2

# %% [markdown]
# Python Program to Read a number n and Compute n+nn+nnn

# %%
x = input("Enter number:")
a = x*2
b = x*3
print(int(x)+int(a)+int(b))
# Out:
# Enter number:1
# 123

# %% [markdown]
# Python Program to Reverse a Given Number

# %%
n = int((input("Number")))
l = [int(i) for i in str(n)]
print(*l[::-1], sep="")
# Out:
# Number123
# 321

# %% [markdown]
#  Python Program to Calculate the Average of Numbers in a Given List

# %%
l = [1,2,3,4,5]
sum = 0
for i in l:
  sum += int(i)
length = len(l)
avg = sum/length
#print(sum,length)
print(avg)
# Out:
# 15 5
# 3.0

# %% [markdown]
# Python Program to Count the Number of Digits in a Number

# %%
n = 1234
l = [int(i) for i in str(n)]
print(len(l))
# Out:
# 4

# %% [markdown]
#  Python Program to Check if a Number is a Palindrome

# %%
n = 13321
a = str(n)
if a == a[::-1]:
  print("Palindrome")
else:
  print("Not Palindrome")
# Out:
# Not Palindrome

# %% [markdown]
# Python Program to print the number of occurrence of a sub string in a given string.

# %%
text = "This is python and it is an interpreted language"
sub = "is"
print(text.count(sub))
# Out:
# 3

# %% [markdown]
#  Python program to print the lowest index in the string where substring sub is found within the
# string

# %%
print(text.index(sub))
# Out:
# 2

# %% [markdown]
# Python Program to return true if all characters in the string are alphabetic and there is at least
# one other character, False

# %%
String1 = "abc9"
if String1.isalpha():
  print("true")
else:
  print("False")
# Out:
# False

# %% [markdown]
# Python Program to Replace all Occurrences of ‘a’ with $ in a String

# %%
String2 = "Fill the glass with a can of soda"
print(String2.replace("a", "$"))
# Out:
# Fill the gl$ss with $ c$n of sod$

# %% [markdown]
# Python Program to Count the Number of Vowels in a String

# %%
if 'a' or 'e' or 'i' or 'o' or 'u' in String1:
  print(String2.count('a')+String2.count('e')+String2.count('i')+String2.count('o')+String2.count('u'))
# Out:
# 1

# %% [markdown]
# Python Program to find the length of string without using any built-in functions

# %%
count = 0
for char in String2:
  count+=1
print(count)
# Out:
# 33

# %% [markdown]
#  Python Program to Take in Two Strings and Display the Larger String without Using Built-in
# Functions

# %%
#length1 = len(String1)
#length2 = len(String2)

count1=0; count2=0;
String1 = "abc9"
String2 = "Fill this glass with a can of soda"

for char in String1:
  count1+=1
for char in String2:
  count2+=1

if count1>count2:
  print("String1 is longer")
else:
  print("String2 is longer")
# Out:
# String2 is longer

# %% [markdown]
# Python Program to Calculate the Number of Upper Case Letters and Lower Case Letters in a
# String

# %%
count_U=0; count_L=0;
String2 = "Fill this glass with a can of soda"

for char in String2:
  if char.isupper():
    count_U+=1
  elif char.islower():
    count_L+=1
  else:
    pass

print(f"No. of uppercase letters {count_U} and no. of lower case letters is {count_L}")
# Out:
# No. of uppercase letters 1 and no. of lower case letters is 25

# %% [markdown]
# Python Program to Calculate the Number of Digits and Letters in a String

# %%
count_digit=0; count_alpha=0;

for char in String1:
  if char.isdigit():
    count_digit+=1
  elif char.isalpha():
    count_alpha+=1
  else:
    pass

print(f"No. of digits is {count_digit} and no. of alphabets is {count_alpha}")
# Out:
# No. of digits is 1 and no. of alphabets is 3

# %% [markdown]
# Python Program to check whether a full pattern (not sub string) is present in the given sentence

# %%
text = "This is python and it is an interpreted language"
pattern = "it is an"

if pattern in text:
  print("Pattern Present")
else:
  print("Pattern not found")
# Out:
# Pattern Present

# %% [markdown]
# Cumulative sum of a list [1, 2, 4, …] is defined as [1, 3, 7, . . .] Write a function
# cumulative_sum() to compute cumulative sum of a list

# %%
L = [1,2,3,4,5]
L1 = []

sum =0
for i in range(len(L)):
  sum+= L[i]
  L1.append(sum)

print(L1)
# Out:
# [1, 3, 6, 10, 15]

# %% [markdown]
# Write a program to generate 10 random integers

# %%
import random

for i in range(1,11):
  print(random.randint(1, 100), end=' ')
# Out:
# 30 65 63 48 42 29 48 28 38 46

# %% [markdown]
# Write a program to generate 10 random integers between 1 to 20 (both inclusive)

# %%
import random
for i in range(1,11):
  print(random.randint(1, 20), end = " ")
# Out:
# 15 7 6 9 8 12 10 14 16 13

# %% [markdown]
# Write a program to generate 5 random integers between 1 to 20 such that numbers should be
# unique

# %%
import random

print(random.sample(range(1,20), 5))
# Out:
# [15, 16, 2, 6, 5]

# %% [markdown]
# Write a program to generate 10 random numbers between 1 to 100 such that there should one
# number between 1 to 10 one number between 11 to 20 etc

# %%
import random

for i in range(1, 101, 10):
  print(random.randint(i, i+9), end = ' ')
# Out:
# 6 16 21 40 45 59 64 73 87 99
